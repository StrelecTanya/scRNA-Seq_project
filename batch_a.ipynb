# %% [markdown]
# **Тема проекта:** Проверка различных программ для батч-коррекции на устойчивость к овер-коррекции
#
#
#
# **Задача:** Искуственно создайте два батча, состоящие из (а) абсолютно разных и (б) частично перекрывающихся типов клеток и выполните батч-коррекцию как минимум тремя методами (Harmony, bbknn и третий по выбору) — охарактеризуйте стабильность каждого из рассмотренных вами методов к овер-коррекции батч-эффекта.

# %% [markdown]
# # Предобработка данных

# %%
# !pip install scanpy[leiden] harmonypy symphonypy bbknn
# Out:
# Collecting harmonypy
#   Downloading harmonypy-0.0.10-py3-none-any.whl.metadata (3.9 kB)
# Collecting symphonypy
#   Downloading symphonypy-0.2.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting bbknn
#   Downloading bbknn-1.6.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting scanpy[leiden]
#   Downloading scanpy-1.10.4-py3-none-any.whl.metadata (9.3 kB)
# Collecting anndata>=0.8 (from scanpy[leiden])
#   Downloading anndata-0.11.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: h5py>=3.6 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (3.12.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (1.4.2)
# Collecting legacy-api-wrap>=1.4 (from scanpy[leiden])
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (3.8.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (3.4.2)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (0.60.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (24.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (2.2.2)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (1.0.1)
# Collecting pynndescent>=0.5 (from scanpy[leiden])
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scikit-learn>=1.1 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (1.5.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (1.13.1)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (0.13.2)
# Collecting session-info (from scanpy[leiden])
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (0.14.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scanpy[leiden]) (4.66.6)
# Collecting umap-learn!=0.5.0,>=0.5 (from scanpy[leiden])
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Collecting igraph>=0.10 (from scanpy[leiden])
#   Downloading igraph-0.11.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting leidenalg>=0.9.0 (from scanpy[leiden])
#   Downloading leidenalg-0.10.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from bbknn) (3.0.11)
# Collecting annoy (from bbknn)
#   Downloading annoy-1.17.3.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 36.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting array-api-compat!=1.5,>1.4 (from anndata>=0.8->scanpy[leiden])
#   Downloading array_api_compat-1.9.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->scanpy[leiden]) (1.2.2)
# Collecting texttable>=1.6.2 (from igraph>=0.10->scanpy[leiden])
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy[leiden]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy[leiden]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy[leiden]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy[leiden]) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy[leiden]) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy[leiden]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy[leiden]) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.56->scanpy[leiden]) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy[leiden]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy[leiden]) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1->scanpy[leiden]) (3.5.0)
# Collecting stdlib_list (from session-info->scanpy[leiden])
#   Downloading stdlib_list-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->scanpy[leiden]) (1.17.0)
# Downloading harmonypy-0.0.10-py3-none-any.whl (20 kB)
# Downloading symphonypy-0.2.1-py3-none-any.whl (27 kB)
# Downloading bbknn-1.6.0-py3-none-any.whl (14 kB)
# Downloading anndata-0.11.1-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.3 MB/s eta 0:00:00
# Downloading igraph-0.11.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.9 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading leidenalg-0.10.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 71.7 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.6 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 7.7 MB/s eta 0:00:00
# Downloading scanpy-1.10.4-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 70.4 MB/s eta 0:00:00
# Downloading array_api_compat-1.9.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.1 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading stdlib_list-0.11.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 6.6 MB/s eta 0:00:00
# Building wheels for collected packages: annoy, session-info
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.3-cp310-cp310-linux_x86_64.whl size=552450 sha256=3225222378376ae00a3b9af32ead423838fd7cb932c4c1ccaebf042ab1e391d7
#   Stored in directory: /root/.cache/pip/wheels/64/8a/da/f714bcf46c5efdcfcac0559e63370c21abe961c48e3992465a
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8023 sha256=53bb3266939ca6bf6c7772e75d953431254ab15e27f25021870142aee3684f2b
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built annoy session-info
# Installing collected packages: texttable, annoy, stdlib_list, legacy-api-wrap, igraph, array-api-compat, session-info, leidenalg, pynndescent, harmonypy, anndata, umap-learn, scanpy, bbknn, symphonypy
# Successfully installed anndata-0.11.1 annoy-1.17.3 array-api-compat-1.9.1 bbknn-1.6.0 harmonypy-0.0.10 igraph-0.11.8 legacy-api-wrap-1.4.1 leidenalg-0.10.2 pynndescent-0.5.13 scanpy-1.10.4 session-info-1.0.0 stdlib_list-0.11.0 symphonypy-0.2.1 texttable-1.7.0 umap-learn-0.5.7

# %% [markdown]
# Загружаем датасет - scRNA-Seq легочной ткани, отобранные от 2х новорожденных девочек

# %%
# !wget https://datasets.cellxgene.cziscience.com/f7be56a5-55fc-4beb-8d5d-ffec21c11906.h5ad -O dataset.h5ad
# Out:
# --2024-12-16 11:50:21--  https://datasets.cellxgene.cziscience.com/f7be56a5-55fc-4beb-8d5d-ffec21c11906.h5ad
# Resolving datasets.cellxgene.cziscience.com (datasets.cellxgene.cziscience.com)... 13.32.151.10, 13.32.151.108, 13.32.151.37, ...
# Connecting to datasets.cellxgene.cziscience.com (datasets.cellxgene.cziscience.com)|13.32.151.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48802893 (47M) [binary/octet-stream]
# Saving to: ‘dataset.h5ad’
#
# dataset.h5ad        100%[===================>]  46.54M  --.-KB/s    in 0.1s
#
# 2024-12-16 11:50:21 (314 MB/s) - ‘dataset.h5ad’ saved [48802893/48802893]

# %% [markdown]
# Импортируем все необходимые библиотеки для обработки данных

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import scanpy as sc
import scanpy.external as sce

# %%
adata = sc.read_h5ad("dataset.h5ad")

# %% [markdown]
# В готовом файле, в adata.X уже предобработанные данные (судя по всему все шаги до шкалирования и отбора HVG). Для более адекватного результата буду работать с сырыми данными и сама их предобработаю.

# %%
# Создание нового объекта adata_raw с сырыми данными
adata_raw = sc.AnnData(adata.raw.X, obs=adata.obs, var=adata.raw.var)

# %%
adata_raw.var["mt"] = adata_raw.var.index.str.startswith("MT-")
sc.pp.calculate_qc_metrics(
    adata_raw,
    qc_vars=["mt"],
    percent_top=None,
    inplace=True,
    log1p=False,
)

# %%
fig, axes = plt.subplots(ncols=3, figsize=(12, 4))

sns.histplot(adata_raw.obs.total_counts, log_scale=True, alpha=1, bins=50, edgecolor="black", ax=axes[0])
axes[0].set_ylabel("")
axes[0].set_xlabel("nUMIs")
axes[0].grid(alpha=0.3)

sns.histplot(adata_raw.obs.n_genes_by_counts, log_scale=True, alpha=1, bins=50, edgecolor="black", ax=axes[1])
axes[1].set_ylabel("")
axes[1].set_xlabel("nGenes")
axes[1].grid(alpha=0.3)

sns.histplot(adata_raw.obs.pct_counts_mt, alpha=1, edgecolor="black", ax=axes[2])
axes[2].set_ylabel("")
axes[2].set_xlabel("% mt counts")
axes[2].grid(alpha=0.3)

fig.tight_layout()

# %%
sc.pp.scrublet(adata_raw, batch_key="donor_id")

# %%
adata_raw = adata[adata_raw.obs.doublet_score <= 0.2].copy()

sc.pp.normalize_total(adata_raw, target_sum=1e4)
sc.pp.log1p(adata_raw)

# %%
sc.pp.highly_variable_genes(adata_raw, batch_key="donor_id", n_top_genes=3000)

adata_raw.raw = adata_raw
adata = adata_raw[:, adata_raw.var.highly_variable]

# %% [markdown]
# Теперь можем отобрать батчи

# %%
#Смотрим какие типы клеток вообще есть в датасете
adata.obs['cell_type'].value_counts()
# Out:
# cell_type
# endothelial cell                  1103
# pericyte                           899
# myofibroblast cell                 815
# fibroblast of lung                 810
# smooth muscle cell                 589
# stromal cell                       412
# macrophage                         345
# T cell                             186
# pulmonary alveolar type 1 cell     129
# B cell                              78
# pulmonary alveolar type 2 cell      76
# Name: count, dtype: int64

# %%
#Отбираем так, чтобы в батчах были разные типы клеток
adata_1 = adata[((adata.obs['cell_type'] == 'endothelial cell') | (adata.obs['cell_type'] == 'pericyte')) & (adata.obs['donor_id'] == 'D038')]
adata_2 = adata[((adata.obs['cell_type'] == 'myofibroblast cell') | (adata.obs['cell_type'] == 'smooth muscle cell')) & (adata.obs['donor_id'] == 'D051')]

# Объединение данных
adata_a = adata_1.concatenate(adata_2)
# Out:
# <ipython-input-11-f998d6e6312b>:6: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_a = adata_1.concatenate(adata_2)

# %%
#Теперь можем стандартизировать данные и сделать PCA
sc.pp.scale(adata_a, max_value=10)
sc.pp.pca(adata_a, n_comps=30)

# %%
#Визуализация без батч-коррекции
# Создаем копию данных
adata_nocorr = adata_a.copy()

# Предобработка данных
sc.pp.neighbors(adata_nocorr)
sc.tl.umap(adata_nocorr)

# Создание подграфиков (subplots)
fig, axes = plt.subplots(1, 3, figsize=(18, 6))  # Увеличиваем ширину фигуры

# Первый график - окрашивание по донору (donor_id)
sc.pl.umap(adata_nocorr, color='donor_id', ax=axes[0], show=False)
axes[0].set_title("UMAP по донору (donor_id)")

# Кластеризация и второй график - окрашивание по кластерам (leiden)
sc.tl.leiden(adata_nocorr, resolution=0.1)
sc.pl.umap(adata_nocorr, color="leiden", ax=axes[1], show=False)
axes[1].set_title("UMAP по кластерам (leiden)")

# Третий график - окрашивание по типам клеток (cell_type)
sc.pl.umap(adata_nocorr, color="cell_type", ax=axes[2], show=False)
axes[2].set_title("UMAP по типам клеток (cell_type)")

# Отображение графиков
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-7ca32b5bc273>:17: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata_nocorr, resolution=0.1)

# %%
df = adata_nocorr.obs.groupby(["leiden", "donor_id"]).size().unstack().T
df = df / df.sum(axis=0)

fig, ax = plt.subplots(figsize=(7, 3))
df.T.plot(kind="bar", stacked=True, width=1, edgecolor="black", ax=ax)
ax.legend(loc=(1.01, 0.5))
# Out:
# <ipython-input-14-96fb93f862c9>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = adata_nocorr.obs.groupby(["leiden", "donor_id"]).size().unstack().T

# %% [markdown]
# Мы видим четкие 4 кластера. В данной симуляции мы не должны видеть батч-эффект, так как клетки у доноров совершенно разные и по-хорошему корректоры не должны смешивать точки.

# %% [markdown]
# # bbKNN

# %%
# Batch balanced kNN

adata_bbknn = adata_a.copy()

import bbknn
bbknn.bbknn(adata_bbknn, batch_key="donor_id", neighbors_within_batch=8)
sc.tl.umap(adata_bbknn)

# Настраиваем подграфики (subplots)
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# График с окрашиванием по batch
sc.pl.umap(adata_bbknn, color="donor_id", ax=axes[0], show=False)
axes[0].set_title("UMAP по batch (donor_id)")

# Кластеризация и второй график - окрашивание по кластерам (leiden)
sc.tl.leiden(adata_bbknn, resolution=0.1)
sc.pl.umap(adata_bbknn, color="leiden", ax=axes[1], show=False)
axes[1].set_title("UMAP по кластерам (leiden)")

# График с окрашиванием по cell_type
sc.pl.umap(adata_bbknn, color="cell_type", ax=axes[2], show=False)
axes[2].set_title("UMAP по cell_type")

# Отображаем графики
plt.tight_layout()
plt.show()

# %%
df = adata_bbknn.obs.groupby(["leiden", "donor_id"]).size().unstack().T
df = df / df.sum(axis=0)

fig, ax = plt.subplots(figsize=(7, 3))
df.T.plot(kind="bar", stacked=True, width=1, edgecolor="black", ax=ax)
ax.legend(loc=(1.01, 0.5))
# Out:
# <ipython-input-16-55f7a966c9c8>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = adata_bbknn.obs.groupby(["leiden", "donor_id"]).size().unstack().T

# %% [markdown]
# bbKNN насильно объединяет точки из разных батчей и только при настройке гиперпараметров (число соседей) можно получить удовлетворительный результат

# %% [markdown]
# # Harmony

# %%
# Harmony
adata_harmony = adata_a.copy()
sce.pp.harmony_integrate(adata_harmony, key="donor_id", max_iter_harmony=30)
sc.pp.neighbors(adata_harmony, use_rep="X_pca_harmony")
sc.tl.umap(adata_harmony)

# Настраиваем подграфики (subplots)
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# График с окрашиванием по batch
sc.pl.umap(adata_harmony, color="donor_id", ax=axes[0], show=False)
axes[0].set_title("UMAP по batch (donor_id)")

# Кластеризация и второй график - окрашивание по кластерам (leiden)
sc.tl.leiden(adata_harmony, resolution=0.1)
sc.pl.umap(adata_harmony, color="leiden", ax=axes[1], show=False)
axes[1].set_title("UMAP по кластерам (leiden)")

# График с окрашиванием по cell_type
sc.pl.umap(adata_harmony, color="cell_type", ax=axes[2], show=False)
axes[2].set_title("UMAP по cell_type")

# Отображаем графики
plt.tight_layout()
plt.show()
# Out:
# 2024-12-16 11:52:53,522 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# INFO:harmonypy:Computing initial centroids with sklearn.KMeans...
# 2024-12-16 11:52:53,847 - harmonypy - INFO - sklearn.KMeans initialization complete.
# INFO:harmonypy:sklearn.KMeans initialization complete.
# 2024-12-16 11:52:53,863 - harmonypy - INFO - Iteration 1 of 30
# INFO:harmonypy:Iteration 1 of 30
# 2024-12-16 11:52:54,144 - harmonypy - INFO - Iteration 2 of 30
# INFO:harmonypy:Iteration 2 of 30
# 2024-12-16 11:52:54,443 - harmonypy - INFO - Converged after 2 iterations
# INFO:harmonypy:Converged after 2 iterations

# %%
df = adata_harmony.obs.groupby(["leiden", "donor_id"]).size().unstack().T
df = df / df.sum(axis=0)

fig, ax = plt.subplots(figsize=(7, 3))
df.T.plot(kind="bar", stacked=True, width=1, edgecolor="black", ax=ax)
ax.legend(loc=(1.01, 0.5))
# Out:
# <ipython-input-18-e3f8a489cabf>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = adata_harmony.obs.groupby(["leiden", "donor_id"]).size().unstack().T

# %%
#Оценим точность кластеризации при каждом методе батч-коррецкии
import sklearn
from sklearn.metrics import adjusted_rand_score

# Предположим, что adata.obs['cell_type'] содержит известные аннотации
ari_nocorr = adjusted_rand_score(adata_nocorr.obs['cell_type'], adata_nocorr.obs['leiden'])
ari_bbknn = adjusted_rand_score(adata_bbknn.obs['cell_type'], adata_bbknn.obs['leiden'])
ari_harmony = adjusted_rand_score(adata_harmony.obs['cell_type'], adata_harmony.obs['leiden'])


print(f'Adjusted Rand Index (ARI) without batch correction: {ari_nocorr:0.2f}')
print(f'Adjusted Rand Index (ARI) with bbKNN: {ari_bbknn:0.2f}')
print(f'Adjusted Rand Index (ARI) with harmony: {ari_harmony:0.2f}')
# Out:
# Adjusted Rand Index (ARI) without batch correction: 0.98
# Adjusted Rand Index (ARI) with bbKNN: 0.57
# Adjusted Rand Index (ARI) with harmony: 0.79

# %% [markdown]
# Результат harmony похож на результат bbKNN, но при томже resolution дает более точный результат

# %% [markdown]
# # Scanorama

# %%
# !pip install scanorama
# Out:
# Collecting scanorama
#   Downloading scanorama-1.7.4-py3-none-any.whl.metadata (525 bytes)
# Requirement already satisfied: annoy>=1.11.5 in /usr/local/lib/python3.10/dist-packages (from scanorama) (1.17.3)
# Collecting fbpca>=1.0 (from scanorama)
#   Downloading fbpca-1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting geosketch>=1.0 (from scanorama)
#   Downloading geosketch-1.3-py3-none-any.whl.metadata (394 bytes)
# Collecting intervaltree>=3.1.0 (from scanorama)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from scanorama) (3.8.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from scanorama) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scanorama) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20rc1 in /usr/local/lib/python3.10/dist-packages (from scanorama) (1.5.2)
# Collecting sortedcontainers<3.0,>=2.0 (from intervaltree>=3.1.0->scanorama)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.2->scanorama) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.2->scanorama) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.2->scanorama) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.2->scanorama) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.2->scanorama) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.2->scanorama) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.2->scanorama) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.2->scanorama) (2.8.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20rc1->scanorama) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20rc1->scanorama) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.2->scanorama) (1.17.0)
# Downloading scanorama-1.7.4-py3-none-any.whl (12 kB)
# Downloading geosketch-1.3-py3-none-any.whl (8.1 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: fbpca, intervaltree
#   Building wheel for fbpca (setup.py) ... done
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11373 sha256=62af7133ac828a0392cd2254d006a07636d28e507f4f07ff1e870ea67c722f8e
#   Stored in directory: /root/.cache/pip/wheels/3c/ea/60/8d1c9fbbc99492a1775b36a5e29c8c1ef309cc5821bd5a219d
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26097 sha256=1c0215bf7861e62a32c5124938a158ec7d0e384223041729dc23a006f756fb77
#   Stored in directory: /root/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
# Successfully built fbpca intervaltree
# Installing collected packages: sortedcontainers, fbpca, intervaltree, geosketch, scanorama
# Successfully installed fbpca-1.0 geosketch-1.3 intervaltree-3.1.0 scanorama-1.7.4 sortedcontainers-2.4.0

# %%
import scanorama

# %%
#Scanorama
from scanorama import correct_scanpy

# Применяем Scanorama к списку объектов AnnData
adatas = [adata_1, adata_2]
adatas_cor = correct_scanpy(adatas, return_dimred=True)

# Создаем новый объект, содержащий объединенные данные
adata_spatial = sc.concat(adatas_cor, label="library_id", uns_merge="unique")
sc.pp.scale(adata_spatial)

# Соседи с использованием откорректированного представления
sc.pp.neighbors(adata_spatial, use_rep="X_scanorama")
sc.tl.umap(adata_spatial)
sc.tl.leiden(adata_spatial, key_added="clusters", n_iterations=2, flavor="igraph", directed=False)
# Out:
# Found 3000 genes among all datasets
# [[0.         0.56744186]
#  [0.         0.        ]]
# Processing datasets (0, 1)
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:797: ImplicitModificationWarning: Trying to modify index of attribute `.obs` of view, initializing view as actual.
#   getattr(self, attr).index = value
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:797: ImplicitModificationWarning: Trying to modify index of attribute `.obs` of view, initializing view as actual.
#   getattr(self, attr).index = value

# %%
# Настраиваем подграфики (subplots)
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# График с окрашиванием по batch
sc.pl.umap(adata_spatial, color="donor_id", ax=axes[0], show=False)
axes[0].set_title("UMAP по batch (donor_id)")

# Кластеризация и второй график - окрашивание по кластерам (leiden)
sc.tl.leiden(adata_spatial, resolution=0.1)
sc.pl.umap(adata_spatial, color="leiden", ax=axes[1], show=False)
axes[1].set_title("UMAP по кластерам (leiden)")

# График с окрашиванием по cell_type
sc.pl.umap(adata_spatial, color="cell_type", ax=axes[2], show=False)
axes[2].set_title("UMAP по cell_type")

# Отображаем графики
plt.tight_layout()
plt.show()

# %%
#Оценим точность кластеризации при каждом методе батч-коррецкии
import sklearn
from sklearn.metrics import adjusted_rand_score

# Предположим, что adata.obs['cell_type'] содержит известные аннотации
ari_nocorr = adjusted_rand_score(adata_nocorr.obs['cell_type'], adata_nocorr.obs['leiden'])
ari_bbknn = adjusted_rand_score(adata_bbknn.obs['cell_type'], adata_bbknn.obs['leiden'])
ari_harmony = adjusted_rand_score(adata_harmony.obs['cell_type'], adata_harmony.obs['leiden'])
ari_scanorama = adjusted_rand_score(adata_spatial.obs['cell_type'], adata_spatial.obs['leiden'])

print(f'Adjusted Rand Index (ARI) without batch correction: {ari_nocorr:0.2f}')
print(f'Adjusted Rand Index (ARI) without bbKNN: {ari_bbknn:0.2f}')
print(f'Adjusted Rand Index (ARI) with harmony: {ari_harmony:0.2f}')
print(f'Adjusted Rand Index (ARI) with scanorama: {ari_scanorama:0.2f}')
# Out:
# Adjusted Rand Index (ARI) without batch correction: 0.98
# Adjusted Rand Index (ARI) without bbKNN: 0.57
# Adjusted Rand Index (ARI) with harmony: 0.79
# Adjusted Rand Index (ARI) with scanorama: 0.79
